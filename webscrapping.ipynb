# %%
# !pip install bs4
# modern way  to install packags is to use % instead of #
# %pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
url= "https://delhi.craigslist.org/search/sof"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data=response.text

# %%
data
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n    \n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n\t<meta name="viewport" content="width=device-width,initial-scale=1">\n\t<meta property="og:site_name" content="craigslist">\n\t<meta name="twitter:card" content="preview">\n\t<meta property="og:title" content="delhi software/qa/dba/etc jobs - craigslist">\n\t<meta name="description" content="delhi software/qa/dba/etc jobs - craigslist">\n\t<meta property="og:description" content="delhi software/qa/dba/etc jobs - craigslist">\n\t<meta property="og:url" content="https://delhi.craigslist.org/search/sof">\n\t<meta name="smartbanner:api" content="true">\n\t<meta name="smartbanner:title" content="the craigslist app">\n\t<meta name="smartbanner:author" content="what&#39;s old is new">\n\t<meta name="smartbanner:icon-apple" content="/images/app_icon.png">\n\t<meta name="smartbanner:icon-google" content="/images/app_icon.png">\n\t<meta name="smartbanner:button" content="
# ...

# %%
soup =BeautifulSoup(data,"html.parser")

# %%
# tags=soup.find_all('a')

titles=soup.find_all("a",{"class":"result-title"})

# %%
# for tag in tags:
  # print(tag.get('href'))
# Out:
# https://delhi.craigslist.org
# /
# https://post.craigslist.org/c/del
# https://accounts.craigslist.org/login/home
# #
# #
# https://delhi.craigslist.org
# https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fdelhi%2Ecraigslist%2Eorg%2Fsearch%2Fsof
# https://delhi.craigslist.org/search/sof
# https://delhi.craigslist.org/search/sof
# /search/sof?sort=date&
# /search/sof?sort=dateoldest&
#
# /search/sof
# /search/sof
#
# https://delhi.craigslist.org/sof/d/developer-php-mysql-vuejs-remote-30/7556220055.html
# https://delhi.craigslist.org/sof/d/developer-php-mysql-vuejs-remote-30/7556220055.html
# #
# https://delhi.craigslist.org/sof/d/inside-sales/7554575935.html
# https://delhi.craigslist.org/sof/d/inside-sales/7554575935.html
# #
# https://delhi.craigslist.org/sof/d/python-django-internship/7552693667.html
# https://delhi.craigslist.org/sof/d/python-django-internship/7552693667.html
# #
# #page-top
# #page-top
# https://www.craigslist.org/about/help/
# ...

# %%
for title in titles:
  print(title.text)
# Out:
# Developer (PHP, MYSQL, VueJS) - Remote 30 Hour / week
# Inside Sales
# Python Django Internship

# %%
adresses= soup.find_all("span",{"class": "result-hood"})

# %%
for address in adresses:
  print(address.text)
# Out:
#  (Delhi)
#  (Noida)
#  (Delhi)

# %%
jobs=soup.find_all('div',{'class': 'result-info'})

# %%
jobs
# Out:
# [<div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-11-11 22:19" title="Fri 11 Nov 10:19:28 PM">Nov 11</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7556220055" href="https://delhi.craigslist.org/sof/d/developer-php-mysql-vuejs-remote-30/7556220055.html" id="postid_7556220055">Developer (PHP, MYSQL, VueJS) - Remote 30 Hour / week</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Delhi)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
# ...

# %%
for job in jobs:
  title = job.find('a',{'class':'result-title hdrlnk'}).text
  location_tag=job.find('span',{'class': 'result-hood'})
  location= location_tag.text[1:-1]  if location_tag else 'N/A'
  date=job.find('time',{'class': 'result-date'}).text
  link=job.find('a',{'class':'result-title'}).get('href')
# loop through each link to get detailed job description
  job_response=requests.get(link)
  job_data=job_response.text
  job_soup = BeautifulSoup(job_data, 'html.parser')
  job_description=job_soup.find('section', {'id':'postingbody'}).text
  job_attributes_tag=job_soup.find('p', {'class':'attrgroup'})
  job_attributes=job_attributes_tag.text if job_attributes_tag else 'N/A'
  print('Job Title:', title, '\nLocation:', location, '\nDate', date, '\nLink:', link,'\n--', job_attributes, '\nJob Description', job_description )
# Out:
# Job Title: Developer (PHP, MYSQL, VueJS) - Remote 30 Hour / week
# Location: (Delhi
# Date Nov 11
# Link: https://delhi.craigslist.org/sof/d/developer-php-mysql-vuejs-remote-30/7556220055.html
# --
# compensation: Reply to discuss
#
# employment type: full-time
#
# job title: Developer (PHP, MYSQL, VueJS) - Remote 30 Hr/Week
#
#
# Job Description
#
# QR Code Link to This Post
#
#
# Looking for a developer with experience in PHP, MYSQL and Vue JS. We are looking for a passionate developer wanting to work in a small startup with long commitment
#
# Job Title: Inside Sales
# Location: (Noida
# Date Nov  7
# Link: https://delhi.craigslist.org/sof/d/inside-sales/7554575935.html
# --
# compensation: 450000
#
# employment type: full-time
#
# job title: Inside Sales
#
#
# Job Description
#
# QR Code Link to This Post
#
#
# The ideal candidate will
#
# •	Stay updated with product knowledge, at all times
# •	Managing life cycle of warm leads into sales
# •	Mustn’t mis-oversell
# ...

# %%
# Moving to next Page
job_no=0
while True:
    response =requests.get(url)
    data= response.text
    soup=BeautifulSoup(data,'html.parser')
    jobs= soup.fnd_all('p',{'class':'result-info'})

    for job in jobs:
      title = job.find('a',{'class':'result-title hdrlnk'}).text
      location_tag=job.find('span',{'class': 'result-hood'})
      location= location_tag.text[1:-1]  if location_tag else 'N/A'
      date=job.find('time',{'class': 'result-date'}).text
      link=job.find('a',{'class':'result-title'}).get('href')
    # loop through each link to get detailed job description
      job_response=requests.get(link)
      job_data=job_response.text
      job_soup = BeautifulSoup(job_data, 'html.parser')
      job_description=job_soup.find('section', {'id':'postingbody'}).text
      job_attributes_tag=job_soup.find('p', {'class':'attrgroup'})
      job_attributes=job_attributes_tag.text if job_attributes_tag else 'N/A'
      job_no+=1
      print('Job Title:', title, '\nLocation:', location, '\nDate', date, '\nLink:', link,'\n--', job_attributes, '\nJob Description', job_description )

    url_tag=soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
      url="https://boston.craiglist.org" + url_tag.get('href')
      print(url)
    else:
      break
    print("Total Jons: ", job_no)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-08e63f395598> in <module>
#       5     data= response.text
#       6     soup=BeautifulSoup(data,'html.parser')
# ----> 7     jobs= soup.fnd_all('p',{'class':'result-info'})
#       8
#       9     for job in jobs:
#
# TypeError: 'NoneType' object is not callable
